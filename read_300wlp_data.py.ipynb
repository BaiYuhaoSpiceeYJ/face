# %%
from scipy.io import loadmat
import cv2

m = loadmat(r'E:\AI\FaceDataset\300W_LP\landmarks\AFW\AFW_9545523490_1_3_pts.mat')
#print(m)#以词典的方式读取

landmark = m['pts_2d']
print(landmark)
m_data = cv2.imread(r'E:\AI\FaceDataset\300W_LP\AFW\AFW_9545523490_1_3.jpg')

for i in range(68):
    cv2.circle(m_data,(int(landmark[i][0]),int(landmark[i][1])),1,(64,250,125),2)#数据，坐标，圆半径，颜色，线条粗细
cv2.imshow('img',m_data)
cv2.waitKey(0)
# Out:
# [[129.97049 254.06628]
#  [134.24352 278.96704]
#  [140.75185 301.03006]
#  [148.0087  320.71988]
#  [158.60922 342.89737]
#  [177.04445 361.3679 ]
#  [199.14053 373.91516]
#  [227.13077 380.61734]
#  [256.54138 382.37976]
#  [280.5574  370.28998]
#  [291.4247  358.65286]
#  [299.92377 348.4051 ]
#  [306.2247  330.7067 ]
#  [308.24924 309.46344]
#  [308.97406 290.6202 ]
#  [309.9933  270.05542]
#  [307.2536  243.5044 ]
#  [175.11084 242.54901]
#  [188.97789 237.47867]
#  [203.31915 233.6895 ]
#  [215.99297 231.69246]
#  [226.81613 232.08586]
#  [266.87213 225.86627]
#  [275.7729  222.96384]
#  [285.39545 221.84872]
#  [295.22342 222.2862 ]
#  [301.01602 224.1826 ]
#  [250.631   256.23724]
#  [255.84555 273.97925]
#  [260.47144 290.51346]
#  [262.0599  303.59985]
#  [240.50357 312.7391 ]
#  [247.89905 313.93808]
#  [256.35208 314.61386]
#  [263.04517 311.7877 ]
#  [266.88654 309.17545]
#  [194.4432  258.49643]
#  [204.49571 254.20433]
#  [214.6821  252.86732]
#  [222.79243 256.5028 ]
# ...
